# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Lab-Task-Final

# %% [markdown]
# This is the final assignment of the Data science course. <br>
# I had learn a lot from it.

# %% [markdown]
# Following are the data science languages
# 1. Python
# 2. R
# 3. SQL
# 4. Java
# 5. JavaScript
# 6. C++
# 7. C
# 8. Scala
# 9. Julia

# %% [markdown]
# Following are the data science languages
# 1. TensorFlow
# 2. NumPy
# 3. Keras
# 4. Pandas
# 5. PyTorch
# 6. Scrapy
# 7. LightGBM
# 8. SciPy
# 9. SciKit-Learn
# 10. Matplotlib

# %% [markdown]
# |**Data Science Tools**|
# |------------------|
# |R|
# |SAS|
# |Python|
# |Spark|

# %% [markdown]
# ## Below is the code of arithmetic expression

# %%
a = 5
b = 4
Sum = a + b
Mul = a * b
print('Sum:', Sum)
print('Multiplication:', Mul)
# Out:
# Sum: 9
# Multiplication: 20

# %%
days = 0
hours = 0
mins = 0

time = 120
leftover_minutes = time % 1440
hours = leftover_minutes / 60
print(str(days) + " days \n" + str(hours) + " hours \n" + str(mins) +  " mins \n")
# Out:
# 0 days
# 2.0 hours
# 0 mins

# %% [markdown]
# The objective of this assignment is
# - To check the knowledge you hav gained throughout this course.
# - To introduce you with different enviroments.

# %% [markdown]
# ### Author <br>
# Aamna
